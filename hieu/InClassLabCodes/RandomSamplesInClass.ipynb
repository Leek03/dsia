# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# array = []
# for i in range(10):
#     array.append(random.randint(-10,10))
# print(array)

# mean = np.mean(array)
# print(mean)
# std = np.std(array)
# print(std)

# count = 0 
# for i in range(10):
#     sample = np.random.rand
    
    
#randn random sample normalised 

sample = np.random.randn(10)
mean = np.mean(sample)
print(mean)
std = np.std(sample)
print(std)

count = 0
for i in range(10):
    sample = np.random.randn(1)
    if abs(sample-mean)>= 2* (std):
        print(sample)
        plt.plot
        print(sample)
        count += 1
        print('I,''ve found outlier')

print(count)
# plt.plot(samples)
# plt.show()
# Out:
# 0.40033246557239915
# 0.8353312144736964
# 0

# %%
#randn random sample normalised 

samples = np.random.randn(10)
mean = np.mean(samples)
# print(mean)
std = np.std(samples)
# print(std)

count = 0
for i in range(10):
    samples[9] = np.random.randn(1)
    if abs(samples[9]-mean)>= 2*(std):
        plt.boxplot(samples)
        plt.show()
        print(samples)
        print(sample)
        count += 1
        print('I,''ve found outlier')

print(count)
# plt.plot(samples)
# plt.show()
# Out:
# [ 0.06833208 -1.44110033  0.2976241  -0.54979513 -0.57463541 -0.49587287
#  -0.98794171  0.50470774 -0.90244481 -1.70156428]
# [0.80646912]
# I,ve found outlier
# [ 0.06833208 -1.44110033  0.2976241  -0.54979513 -0.57463541 -0.49587287
#  -0.98794171  0.50470774 -0.90244481  1.45550494]
# [0.80646912]
# I,ve found outlier
# [ 0.06833208 -1.44110033  0.2976241  -0.54979513 -0.57463541 -0.49587287
#  -0.98794171  0.50470774 -0.90244481  1.42827424]
# [0.80646912]
# I,ve found outlier
# [ 0.06833208 -1.44110033  0.2976241  -0.54979513 -0.57463541 -0.49587287
#  -0.98794171  0.50470774 -0.90244481  1.30767549]
# [0.80646912]
# I,ve found outlier
# 4

# %%
#randn random sample normalised 

samples = np.random.randn(10)
mean = np.mean(samples)
# print(mean)
std = np.std(samples)
# print(std)

count = 0
for i in range(10):
    samples[9] = np.random.randn(1)
    if abs(samples[9]-mean)>= 2*(std):
        plt.show()
        print(samples)
        print(sample)
        count += 1
        print('I,''ve found outlier')

print(count)
sns.violinplot(samples);
# plt.plot(samples)
# plt.show()

# sns.set(style="whitegrid")
# tips = sns.load_dataset("tips")
# ax = sns.violinplot(x=tips["total_bill"])
# Out:
# [ 0.11849003  0.59125223  0.83777494  0.11597316  1.42259521  0.02535699
#   0.25813469  2.36950967  1.6755224  -2.21539428]
# [0.80646912]
# I,ve found outlier
# [ 0.11849003  0.59125223  0.83777494  0.11597316  1.42259521  0.02535699
#   0.25813469  2.36950967  1.6755224  -1.3662641 ]
# [0.80646912]
# I,ve found outlier
# 2

# %%
#randn random sample normalised 

samples = np.random.randn(11)
mean = np.mean(samples[0:10])
# print(mean)
std = np.std(samples[:10])
# print(std)

count = 0
for i in range(10):
    samples[10] = np.random.randn(1)
    if abs(samples[10]-mean)>= 2*(std):
        plt.show()
        print(samples)
        print(sample)
        count += 1
        print('I,''ve found outlier')

print(count)
sns.violinplot(samples);
# plt.plot(samples)
# plt.show()

# sns.set(style="whitegrid")
# tips = sns.load_dataset("tips")
# ax = sns.violinplot(x=tips["total_bill"])
# Out:
# [-2.70559858  0.06058417  0.3068922   0.92118394  0.75619698  0.17837156
#  -0.40282929 -0.51652532 -1.17229709  1.46204361  2.68268943]
# [0.80646912]
# I,ve found outlier
# [-2.70559858  0.06058417  0.3068922   0.92118394  0.75619698  0.17837156
#  -0.40282929 -0.51652532 -1.17229709  1.46204361  2.28826967]
# [0.80646912]
# I,ve found outlier
# 2

# %%
import pandas as pd
import numpy as np

# %%
drug = pd.read_csv('datasets/drug-use-by-age.csv', index_col=0) #Remove the index , index_col=0)

drug.head()
# Out:
#         n  alcohol-use  alcohol-frequency  marijuana-use  marijuana-frequency  \
# age
# 12   2798          3.9                3.0            1.1                  4.0
# 13   2757          8.5                6.0            3.4                 15.0
# 14   2792         18.1                5.0            8.7                 24.0
# 15   2956         29.2                6.0           14.5                 25.0
# 16   3058         40.1               10.0           22.5                 30.0
#
#      cocaine-use cocaine-frequency  crack-use crack-frequency  heroin-use  \
# age
# 12           0.1               5.0        0.0               -         0.1
# 13           0.1               1.0        0.0             3.0         0.0
# 14           0.1               5.5        0.0               -         0.1
# 15           0.5               4.0        0.1             9.5         0.2
# 16           1.0               7.0        0.0             1.0         0.1
#
# ...

# %%
drug.describe()
# Out:
#                  n  alcohol-use  alcohol-frequency  marijuana-use  \
# count    17.000000    17.000000          17.000000      17.000000
# mean   3251.058824    55.429412          33.352941      18.923529
# std    1297.890426    26.878866          21.318833      11.959752
# min    2223.000000     3.900000           3.000000       1.100000
# 25%    2469.000000    40.100000          10.000000       8.700000
# 50%    2798.000000    64.600000          48.000000      20.800000
# 75%    3058.000000    77.500000          52.000000      28.400000
# max    7391.000000    84.200000          52.000000      34.000000
#
#        marijuana-frequency  cocaine-use  crack-use  heroin-use  \
# count            17.000000    17.000000  17.000000   17.000000
# mean             42.941176     2.176471   0.294118    0.352941
# std              18.362566     1.816772   0.235772    0.333762
# min               4.000000     0.000000   0.000000    0.000000
# ...

# %%
rows, cols = drug.shape # row and columns and save

# %%
drug.tail(10)
# Out:
#           n  alcohol-use  alcohol-frequency  marijuana-use  \
# age
# 19     2223         64.6               36.0           33.4
# 20     2271         69.7               48.0           34.0
# 21     2354         83.2               52.0           33.0
# 22-23  4707         84.2               52.0           28.4
# 24-25  4591         83.1               52.0           24.9
# 26-29  2628         80.7               52.0           20.8
# 30-34  2864         77.5               52.0           16.4
# 35-49  7391         75.0               52.0           10.4
# 50-64  3923         67.2               52.0            7.3
# 65+    2448         49.3               52.0            1.2
#
#        marijuana-frequency  cocaine-use cocaine-frequency  crack-use  \
# age
# 19                    60.0          4.1               5.5        0.5
# 20                    60.0          4.9               8.0        0.6
# 21                    52.0          4.8               5.0        0.5
# ...

# %%
drug.columns
# Out:
# Index(['n', 'alcohol-use', 'alcohol-frequency', 'marijuana-use',
#        'marijuana-frequency', 'cocaine-use', 'cocaine-frequency', 'crack-use',
#        'crack-frequency', 'heroin-use', 'heroin-frequency', 'hallucinogen-use',
#        'hallucinogen-frequency', 'inhalant-use', 'inhalant-frequency',
#        'pain-releiver-use', 'pain-releiver-frequency', 'oxycontin-use',
#        'oxycontin-frequency', 'tranquilizer-use', 'tranquilizer-frequency',
#        'stimulant-use', 'stimulant-frequency', 'meth-use', 'meth-frequency',
#        'sedative-use', 'sedative-frequency'],
#       dtype='object')

# %%
#drug. . and tab to see all. 
#shift tab twice VERY IMPORTANT!!!!

drug['alcohol-use'].head()
# Out:
# age
# 12     3.9
# 13     8.5
# 14    18.1
# 15    29.2
# 16    40.1
# Name: alcohol-use, dtype: float64

# %%
drug[['alcohol-use']].head() #get a dataframe
# Out:
#      alcohol-use
# age
# 12           3.9
# 13           8.5
# 14          18.1
# 15          29.2
# 16          40.1

# %%
print(type('alcohol-use'))
# Out:
# <class 'str'>

# %%
drug['alcohol-use'].unique()
# Out:
# array([ 3.9,  8.5, 18.1, 29.2, 40.1, 49.3, 58.7, 64.6, 69.7, 83.2, 84.2,
#        83.1, 80.7, 77.5, 75. , 67.2])

# %%
#print((type(drug['age'])))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-b08228082363> in <module>
# ----> 1 print((type(drug['age'])))
# ...

# %%
drug.info()

# %%
#esc and enter(return)
drug[['age']].describe()
##homework to do the subset change from object to int??

# %%
drug.groupby('age').count()

# %%
drug[drug.crack_use == 'crack-use'].groupby(['age', 'heroin-use']).count()
#article_read[article_read.country == 'country_2'].groupby(['source', 'topic']).count()

# %%
diamonds = pd.read_csv('datasets/diamonds.csv')
print

# %%
drug[(drug['age']>20) & (drug.n > 4000)]

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
purchases = pd.DataFrame(data)

purchases

purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])

purchases

purchases.loc['June']

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s

# %%
s.index

# %%
s = pd.Series(['Tiger', 'Bear', 'Moose'], index=['India', 'America', 'Canada'])
s

# %%
len(df[(df['Price'] > 0) | (df['Price'] > 0)])

# %%
#import all the diamond csv
diamond= pd.read_csv('datasets/diamonds.csv')
# Get the name of the CSV.
diamond.columns

# %%
# Convert diamond carat to Series (Series can only ever have 1 column (plus an index).)
dc = diamond['carat'][:10] #only wanted 10 rows since it too much. 
pd.Series(dc)

# sample code
# data = np.random.rand(5)
# pd.Series(data)

# %%
diamond.head(2)

# %%
diamond2 = pd.DataFrame(diamond,index=['A', 'B', 'C', 'D', 'E'],columns=['I get to choose the name', 'col2', 'col3', 'col4', 'col5'])
diamond2

# %%
#I was testing lamda.
diamond.index = [lambda:i for i in range(53940)]
diamond.head(5)

# %%
# using the np range from 1 to 53940 an index.
diamond.index = np.arange(1,53941) 
diamond.head(5)

# %% [markdown]
# tomorrow to do the sum and equations.

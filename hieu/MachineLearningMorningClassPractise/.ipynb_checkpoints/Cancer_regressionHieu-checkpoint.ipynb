# %% [markdown]
# ### All my packages/imports

# %%
# -*- coding: utf-8 -*- Earnest
""" Tuesday -Hieu Practise23-7-19 6pm 1:, practise 10 times:
1: After first session save to my drive, see if I could run it on the large MAC. 
"""
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.model_selection import train_test_split

# %% [markdown]
# Shift tab
# prev_val = 1e+20 (ten to the power of 20)
# Alpha =  hyper parameter learning rate...
# Predictor = df['registered'] # use to column to train pick only features.
# x_train = np.column_stack((np.ones(len(predictor)),predictor).   Pass the predictor and the length to np.ones all with np.ones.
#
# Shift tab twice to get auto type
# np.column_stack tranpose.
# predictorprice = getDotProduct
# Training loss store
# Calculateloss= calculateCOst and reducing the errors

# %% [markdown]
# ### All my functions

# %%
def plotFeatures(col_list,title):
    plt.figure(figsize=(10, 14))
    i = 0
    print(len(col_list))
    for col in col_list:
        i+=1
        plt.subplot(8,2,i)
        plt.plot(df[col],df["cnt"],marker='.',linestyle='none')
        plt.title(title % (col))   
        plt.tight_layout()
        
def getDotProduct(x,theta):
    print('np.dot of x,theta',np.dot(x,theta))
    return np.dot(x,theta)

def calculateLoss(x,theta,Y):
    prediction = getDotProduct(x,theta)
    return ((prediction - Y)**2).mean()/2

def abline(x,theta,Y):
    """Plot a line from slope and intercept"""
    y_vals = getDotProduct(x,theta)
    plt.figure(figsize=(15, 20))
    plt.xlim(0, 20)
    plt.ylim(-10, 60)
    plt.xlabel('registered')
    plt.ylabel('count')
    plt.gca().set_aspect(0.1, adjustable='datalim')
    plt.plot(x,Y,'.',x, y_vals, '-')
    plt.show()
    
def gradientDescentLinearRegression(alpha=0.0001,iter=20000):
    '''initialized the values'''
    theta = np.zeros(2)
    prev_val =1e+20
    counter =0
    theta0 = []
    theta1 = []
    costs_train = []
    costs_val = []
    
    '''provide the training information'''
    predictor = df_train["registered"]
    x_train = np.column_stack((np.ones(len(predictor)),predictor))
    print("x_train:", x_train)
    Y_train = df_train["cnt"] 
    
    '''provide the validation information'''
    predictor_val = df_val["registered"]
    x_val = np.column_stack((np.ones(len(predictor_val)),predictor_val))
    Y_val = df_val["cnt"]
       
    '''Do for number of iter'''
    for i in range(iter):
        '''do the prediction'''
        pred_dot_prod = getDotProduct(x_train,theta)
        print('pred_dot_prod = ', pred_dot_prod)
        '''' correct the gradient '''
        t0 = theta[0] - alpha *(pred_dot_prod - Y_train).mean()
        print('theta[0] = ',theta[0])
        print('alpha = ',alpha)
        print('pred_dot_prod = ',pred_dot_prod)
        print('Y_train = ',Y_train)
        print('alpha *(pred_dot_prod - Y_train).mean() = ',alpha *(pred_dot_prod - Y_train).mean())
        print('t0 = ',t0)
        
        t1 = theta[1] - alpha *((pred_dot_prod - Y_train)* x_train[:,1]).mean()
        
        print('theta[1] = ',theta[1])
        print('alpha = ',alpha)
        print('pred_dot_prod = ',pred_dot_prod)
        print('Y_train = ',Y_train)
        print('Y_train.shape',Y_train.shape)
        print('alpha *((pred - Y_train)* x_train[:,1]).mean() = ',alpha *((pred_dot_prod - Y_train)* x_train[:,1]).mean())
        print('t1 = ',t1)
        
        theta = np.array([t0,t1])
        print('theta = ',theta)
           
        ''' training loss '''
        J_train = calculateLoss(x_train,theta,Y_train)
        theta0.append(t0)
        theta1.append(t1)
        costs_train.append(J_train)
        '''validation loss'''
        J_val = calculateLoss(x_val,theta,Y_val)
        costs_val.append(J_val)
        print(f"Iteration: {i+1},Cost = {J_train},theta = {theta}")
            
        print(f"Iteration: {i+1},Cost_val = {J_val},theta = {theta}")
        if i%1000==0:
            print(f"Iteration: {i+1},Cost = {J_train},theta = {theta}")
            
            print(f"Iteration: {i+1},Cost_val = {J_val},theta = {theta}")
            
            abline(x_train,theta,Y_train)
        if J_val>prev_val:
            counter +=1   #counter = counter + 1
            prev_val = J_val
        else:
            counter = 0
            prev_val = J_val
        '''check the termination condition''' 
#        print ( J_val,prev_val,counter,i)
        if counter>100:
            print ("terminated")
            print(f'theta0 = {len(theta0)}\ntheta1 = {len(theta1)}\nCosts = {len(costs_train)}')
            print ( J_val,prev_val,counter,i)
            return costs_val,costs_train,theta,i+1
            
#            abline(x_train,theta,Y_train)
    print(f'theta0 = {len(theta0)}\ntheta1 = {len(theta1)}\nCosts = {len(costs_train)}')
    return costs_val,costs_train,theta,iter        
#        print(f'theta0 = {len(theta0)}\ntheta1 = {len(theta1)}\nCosts = {len(costs_val)}')

# %% [markdown]
# ### Main body of the program

# %%
# style.use('fivethirtyeight')
df = pd.read_csv("hour.csv",header =0) 
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
#housing_colnames = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
#df.columns = housing_colnames
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
# instant       17379 non-null int64
# dteday        17379 non-null object
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# casual        17379 non-null int64
# registered    17379 non-null int64
# cnt           17379 non-null int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
colnames = df.columns
print(f'{colnames} \nshape: {df.shape}')
# Out:
# Index(['instant', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')
# shape: (17379, 16)

# %%
df.drop(['dteday'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['instant', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df_A,df_test = train_test_split(df, test_size=0.20, random_state=1001)

# %%
df_train,df_val = train_test_split(df_A, test_size=0.20, random_state=1001)

# %%
print(df_A.shape, df_train.shape,df_val.shape)
# Out:
# (13903, 16) (11122, 16) (2781, 16)

# %%
#colnames = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
plotFeatures(df.columns,"Relationship btw %s and cnt")
# plt.matshow(df.corr())
#fig = plt.subplots(figsize = (10,10))
#sns.set(font_scale=1.5)
#sns.heatmap(df.corr(),square = True,cbar=True,annot=True,annot_kws={'size': 10})
plt.show()
# Out:
# 16

# %%
plotFeatures(df.columns,"Relationship btw %s and cnt")
plt.show()
# Out:
# 16

# %%
costs_val,costs_train,theta,iteration  = gradientDescentLinearRegression(alpha=0.0001,iter=2)
# Out:
# x_train: [[  1.  32.]
#  [  1. 129.]
#  [  1.   1.]
#  ...
#  [  1.   9.]
#  [  1.  11.]
#  [  1.  11.]]
# np.dot of x,theta [0. 0. 0. ... 0. 0. 0.]
# pred_dot_prod =  [0. 0. 0. ... 0. 0. 0.]
# theta[0] =  0.0
# alpha =  0.0001
# pred_dot_prod =  [0. 0. 0. ... 0. 0. 0.]
# Y_train =  5582      41
# 6000     189
# 3869       1
# 3207     122
# 14770    318
# 14933    192
# 7102     228
# 138       17
# 12314     86
# 11316    568
# 2418     243
# 5739     198
# 7298     334
# 13124     29
# 5162      30
# 12468    793
# 15098    532
# 10616    318
# 17213     13
# 8331     135
# 285      202
# 3677       2
# 1459      32
# 16210      9
# 1835      12
# 6288     390
# 15612    888
# 1582      78
# 5500       8
# 6096     225
#         ...
# 12013    474
# 5372     570
# 2302     131
# 1320      92
# 14378    433
# 14987    567
# 9745      23
# 4011      14
# 16547     31
# 8748     388
# 14543     11
# 5960     230
# 10042    163
# 15474    186
# 16153    283
# 11605    706
# ...

# %%
'''prepare the test data'''
predictor_test = df_test["registered"]
x_test = np.column_stack((np.ones(len(predictor_test)),predictor_test))
Y_test = df_test["cnt"]

# %%
'''plot the test data'''
y_test_vals = getDotProduct(x_test,theta)
plt.figure(figsize=(15, 20))
plt.xlim(0, 20)
plt.ylim(-10, 60)
plt.xlabel('registered')
plt.ylabel('count')
plt.gca().set_aspect(0.1, adjustable='datalim')
plt.plot(x_test,Y_test,'.',x_test, y_test_vals, '-')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-7b1b05f5ee76> in <module>
#       1 '''plot the test data'''
# ----> 2 y_test_vals = getDotProduct(x_test,theta)
#       3 plt.figure(figsize=(15, 20))
#       4 plt.xlim(0, 20)
#       5 plt.ylim(-10, 60)
#
# NameError: name 'theta' is not defined

# %%
'''Calculate the loss for test data'''
J_test = calculateLoss(x_test,theta,Y_test)
print(f"Cost_test = {J_test}")
''' create range of iteration'''
x=list(range(0, iteration))
'''plot the loss information'''
plt.figure(figsize=(15, 20))
plt.xlabel('No. of iteration')
plt.ylabel('Loss')
plt.plot(x,costs_train,'.',x, costs_val, '-')
plt.show()


# def plotFeatures(col_list,title):
#     plt.figure(figsize=(10, 14))
#     i = 0
#     print(len(col_list))
#     for col in col_list:
#         i+=1
#         plt.subplot(8,2,i)
#         plt.plot(df[col],df["cnt"],marker='.',linestyle='none')
#         plt.title(title % (col))   
#         plt.tight_layout()
        
# def getDotProduct(x,theta):
#     print('np.dot of x,theta',np.dot(x,theta))
#     return np.dot(x,theta)

# def calculateLoss(x,theta,Y):
#     prediction = getDotProduct(x,theta)
#     return ((prediction - Y)**2).mean()/2

# def abline(x,theta,Y):
#     """Plot a line from slope and intercept"""
#     y_vals = getDotProduct(x,theta)
#     plt.figure(figsize=(15, 20))
#     plt.xlim(0, 20)
#     plt.ylim(-10, 60)
#     plt.xlabel('registered')
#     plt.ylabel('count')
#     plt.gca().set_aspect(0.1, adjustable='datalim')
#     plt.plot(x,Y,'.',x, y_vals, '-')
#     plt.show()
    
# def gradientDescentLinearRegression(alpha=0.0001,iter=20000):
#     '''initialized the values'''
#     theta = np.zeros(2)
#     prev_val =1e+20
#     counter =0
#     theta0 = []
#     theta1 = []
#     costs_train = []
#     costs_val = []
    
#     '''provide the training information'''
#     predictor = df_train["registered"]
#     x_train = np.column_stack((np.ones(len(predictor)),predictor))
#     print("x_train:", x_train)
#     Y_train = df_train["cnt"] 
    
#     '''provide the validation information'''
#     predictor_val = df_val["registered"]
#     x_val = np.column_stack((np.ones(len(predictor_val)),predictor_val))
#     Y_val = df_val["cnt"]
       
#     '''Do for number of iter'''
#     for i in range(iter):
#         '''do the prediction'''
#         pred_dot_prod = getDotProduct(x_train,theta)
#         print('pred_dot_prod = ', pred_dot_prod)
#         '''' correct the gradient '''
#         t0 = theta[0] - alpha *(pred_dot_prod - Y_train).mean()
#         print('theta[0] = ',theta[0])
#         print('alpha = ',alpha)
#         print('pred_dot_prod = ',pred_dot_prod)
#         print('Y_train = ',Y_train)
#         print('alpha *(pred_dot_prod - Y_train).mean() = ',alpha *(pred_dot_prod - Y_train).mean())
#         print('t0 = ',t0)
        
#         t1 = theta[1] - alpha *((pred_dot_prod - Y_train)* x_train[:,1]).mean()
        
#         print('theta[1] = ',theta[1])
#         print('alpha = ',alpha)
#         print('pred_dot_prod = ',pred_dot_prod)
#         print('Y_train = ',Y_train)
#         print('Y_train.shape',Y_train.shape)
#         print('alpha *((pred - Y_train)* x_train[:,1]).mean() = ',alpha *((pred_dot_prod - Y_train)* x_train[:,1]).mean())
#         print('t1 = ',t1)
        
#         theta = np.array([t0,t1])
#         print('theta = ',theta)
           
#         ''' training loss '''
#         J_train = calculateLoss(x_train,theta,Y_train)
#         theta0.append(t0)
#         theta1.append(t1)
#         costs_train.append(J_train)
#         '''validation loss'''
#         J_val = calculateLoss(x_val,theta,Y_val)
#         costs_val.append(J_val)
#         print(f"Iteration: {i+1},Cost = {J_train},theta = {theta}")
            
#         print(f"Iteration: {i+1},Cost_val = {J_val},theta = {theta}")
#         if i%1000==0:
#             print(f"Iteration: {i+1},Cost = {J_train},theta = {theta}")
            
#             print(f"Iteration: {i+1},Cost_val = {J_val},theta = {theta}")
            
#             abline(x_train,theta,Y_train)
#         if J_val>prev_val:
#             counter +=1   #counter = counter + 1
#             prev_val = J_val
#         else:
#             counter = 0
#             prev_val = J_val
#         '''check the termination condition''' 
# #        print ( J_val,prev_val,counter,i)
#         if counter>100:
#             print ("terminated")
#             print(f'theta0 = {len(theta0)}\ntheta1 = {len(theta1)}\nCosts = {len(costs_train)}')
#             print ( J_val,prev_val,counter,i)
#             return costs_val,costs_train,theta,i+1
            
# #            abline(x_train,theta,Y_train)
#     print(f'theta0 = {len(theta0)}\ntheta1 = {len(theta1)}\nCosts = {len(costs_train)}')
#     return costs_val,costs_train,theta,iter        
# #        print(f'theta0 = {len(theta0)}\ntheta1 = {len(theta1)}\nCosts = {len(costs_val)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-5583d174a696> in <module>
#       1 '''Calculate the loss for test data'''
# ----> 2 J_test = calculateLoss(x_test,theta,Y_test)
#       3 print(f"Cost_test = {J_test}")
#       4 ''' create range of iteration'''
#       5 x=list(range(0, iteration))
#
# NameError: name 'theta' is not defined
